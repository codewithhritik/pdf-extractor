# %%
import requests
from pdf2image import convert_from_bytes
import pytesseract
from PIL import Image
import pandas as pd

# %%
pdf_urls = {
    "English": "https://health.hawaii.gov/mauiwildfires/files/2023/08/DOH-Fact-Sheet-Lahaina-CHC.pdf",
    "Hawaiian": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_HAW.pdf",
    "Marshallese": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_MH.pdf",
    "Chuukese": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_CHK.pdf",
    "Pohnpeian": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_PON.pdf",
    "Tongan": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_TO.pdf",
    "Kosraean": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_KOS.pdf"
}

# %%
def download_pdf(url):
    """Download PDF from a given URL and return the content."""
    response = requests.get(url)
    response.raise_for_status()  # Ensures we notice bad responses
    return response.content

# %%
def pdf_to_images(pdf_content):
    """Convert PDF byte content to a list of PIL Images."""
    return convert_from_bytes(pdf_content)

def extract_text_from_images(images):
    """Extract text from a list of PIL Images using Tesseract OCR with the English language pack."""
    full_text = ""
    for image in images:
        text = pytesseract.image_to_string(image, lang='eng')
        full_text += text + "\n"
    return full_text

# %%
def segment_text_to_paragraphs(text):
    # Simple segmentation based on two newlines; adjust as needed
    paragraphs = [para.strip() for para in text.split("\n\n") if para.strip()]
    return paragraphs

# %%
def process_pdf(url):
    pdf_content = download_pdf(url)
    images = pdf_to_images(pdf_content)
    text = extract_text_from_images(images)
    paragraphs = segment_text_to_paragraphs(text)
    return paragraphs

# %%
data = {
    "English": [],
    "Hawaiian": [],
    "Marshallese": [],
    "Chuukese": [],
    "Pohnpeian": [],
    "Tongan": [],
    "Kosraean": []
}

# %%
for language, url in pdf_urls.items():
    print(f"Processing {language} PDF...")
    paragraphs = process_pdf(url)
    data[language].extend(paragraphs)
# Out:
# Processing English PDF...
# Processing Hawaiian PDF...
# Processing Marshallese PDF...
# Processing Chuukese PDF...
# Processing Pohnpeian PDF...
# Processing Tongan PDF...
# Processing Kosraean PDF...

# %%
data
# Out:
# {'English': ['® seavoratreiricuwe WIEST MAUI HEALTH SERVICES',
#   'MAUI COUNTY',
#   'ama I Ke Local Clinic Services',
#   'Lahaina Comprehensive Health Center',
#   '& Malama | Ke Ola',
#   'Medical Services',
#   'Hours: Monday - Friday',
#   '9:00 AM - 4:00 PM',
#   'Contact: (808) 871-7772\nAppointments Recommended',
#   'Insurance Accepted: Medicare,\nMedicaid & major insurance plans\n(except Kaiser, Humana & Tricare)',
#   'Services',
#   'e Adult Medicine: Monday-Friday\ne Pediatrics: Monday',
#   'e Integrated Health: Tuesday',
#   'e Dental Care: Wednesday',
#   '9 @ Lahaina Civic Center',
#   'Lahaina Civic\nCenter Tickets',
#   'Lahaina Comprehensive\nHealth Center',
#   '_ Location:\nAkoakoa Place (just below',
#   'Lahaina Civic Center)\nWayside Park\nintipark with BBQs & pavilions',
#   'fan\\',
#   '*Hours and services subject to change',
#   'Behavioral Health',
#   'Hours: Monday - Sunday',
#   '9:00 AM - 4:00 PM',
#   'Contact: (808) 495-5113\nWalk-Ins Welcome',
#   'Insurance Accepted But Not Required',
#   'Adult & Youth Services',
#   'Resource Guidance',
#   'Supportive Counseling: Individual,\nGroup, and Family',
#   'Medication Management',
#   'Psychiatric Services',
#   'Outpatient Substance Use Disorder\nServices',
#   'Wellness Support Groups - Parenting,\nStress Management & Mindfulness',
#   'Mauliola\nPharmacy',
#   'CLINICAL LABS\nOF HAWAII',
#   'HUI NO KE OLA PONG\nQuestions? Call (808) 495-5113',
#   'LCHC\nUpdated 10/18/23'],
#  'Hawaiian': ['® senaworatnearmcume = WV EST MAUI HEALTH SERVICES',
#   'MAUI COUNTY\na',
#   'a. ; —_ =\nCvecmucce Na Hana Lawelawe ona',
#   'Ke‘ena Kauka Kuloko',
#   'Lahaina Comprehensive Health Center',
#   'Na Hana Lawelawe Olakino',
#   'Na Hola: Pd‘akahi - Pd‘alima\n9:00 AM - 4:00 PM\nKelepona: (808) 871-7772\nPaipai ‘ia e Ho‘opa‘a i ka Halawai\n‘Ae ‘ia ka ‘Inikua: Medicare, Medicaid a me',
#   'na papa hana ‘inikua inoa kaulana (koe ke\nKaiser, Humana & Tricare)',
#   'Na Hana Lawelawe\ne La‘au Kanaka Makua: Po‘akahi - Po‘alima\ne Lapa‘au Keiki: Po‘akahi\ne Na Ninau Like ‘Ole 0 ke Olakino: Pd‘alua\ne Dental Care: Pd‘akolu',
#   '9 Lahaina Civic Center\nGshaina Civic',
#   'Center Tickets',
#   'Lahaina Comprehensive\nHealth Center',
#   'Kahi:',
#   '‘Akoakoa Place (ma kai iki o ka\nLahaina Civic Center)\nWahikuli\nWayside Park\nBBQ',
#   'otipark with BBQs',
#   '& pavilions',
#   'fan\\',
#   '*Hiki ke loli na hola a me na hana lawelawe\nWest Maui Health Services, Updated 10/18/23\nHawaiian',
#   'Kialana No’ono’o i ka Hanah',
#   'Na Hola: Po’akahi - Lapule\n9:00 AM - 4:00 PM\nKelepona: (808) 495-5113\n‘Ae ‘ia ka Po’e Komo Wale mai',
#   '‘Ae ‘ia ka ‘Inikua, aka, ‘A‘ole Pono',
#   'Na Hana Lawelawe no na Kanaka\nMakua a me na ‘Opio',
#   'Kuhikuhi Kumu Waiwai',
#   'e Kauleo Kako’o: No ke Kanaka, ka Hui, a me ka\n‘Ohana',
#   'e Ho’omalu La‘au Lapa‘au',
#   'e Kauka Kilana No‘ono‘o',
#   'e Na Hana Lawelawe Hei ‘Ai La‘au Pakela no ka\nLa Wale no',
#   'e Na Hui Kako‘o Ola Pono - Ka Hana a na Makua,\nHo‘omalu Uluhua a me ka Maluhia 0 ka Mana‘o',
#   'Mauliola\nPharmacy',
#   'CLINICAL LABS\nOF HAWAII',
#   'HUI NO KE Gag OLA PONO',
#   'Loa‘a no ka ninau? E kelepona i ka helu\n(808) 495-5113',
#   'LCHC\nHo‘oponopono ‘ia 10/18/23'],
#  'Marshallese': ['Boe y. CERTIFIED COMMUNITY\n®\n“lash',
#   'HEALTH CENTER',
#   'sy\nva .\nPAE Malama I Ke Ola',
#   'Sennvionateatimcume JB ANY IN EJMOUR KO ILO RAK IN MAUI\nJiban ko ilo Jikin Takto ko',
#   'Redik ilo Jukjukinbed',
#   'Lahaina Comprehensive Health Center\nJiban in Ejmour Naninmij ko ilo Manit',
#   'Awa ko: Mande - Bolaide\n9:00 Awa Jibbon - 4:00 Awa Raelap\nNomba eo fian Kebaak: (808) 871-7772\nEm6j Réjafi Kar6k Awa im Raan eo Kw6nqj Etal',
#   'Rej Ebdk Injuran Medicare, Medicaid\n& im injuran ko relab (ijellokun Kaiser,\nHumana & Tricare)',
#   'Jerbal in Jibafh ko\ne Jikin Takt6 eo an Ratto: Mande-Bolaide\ne Jikin Takt6 eo an Ajiri: Mande\ne Integrated Health: Tuje\ne Taktd in Ni: Wenje',
#   '9 Lahaina Civic Center\nPshaina Civic',
#   'Center Tickets\nLahaina Comprehensive\nHealth Center',
#   'Jikin:\nAkoakoa Place (ilalin wot\nLahaina Civic Center)',
#   'Wayside Park\nntparkiwith BBQs & pavilions\n*Awa in jerbal in jibafh ko remaron oktak',
#   'West Maui Health Services, Updated 10/18/23\nMarshallese',
#   'Awa ko: Mande - Jabot',
#   '9:00 Awa jibbon - 4:00 Awa Raelap',
#   'Nomba eo fian Kebaak: (808) 495-5113\nRej Karuwainene an Armij Kaju Itok',
#   'Rej Ebdk Injuran Botab Ejab Mennin Aikuj an Wér',
#   'Jibah han Ratto & Jodikdik',
#   'e Melele in Kajinet kin Mennin Jibafh',
#   'e Koonjel fan Lelok Jibafi: Kajojo Armij,\nKumi in Armij, im Baamle',
#   'e Lale len Ebék Wuno',
#   'e Jjibafi ko ilo Waween Lomnak',
#   'e Jibaf ko fan Jorraan jen Kéjerbal Wano\nKajur ilo an Rinafiinmij Jab Delof Aujbitol',
#   'e Kumi in Jibafi kin Ainemmon im Ejmour -\nNejnej, Lale Inebata & Jela Lomnak',
#   'Jikin ko jej Jerbal Ibbeir',
#   'Mauliola\nPharmacy',
#   'CLINICAL LABS\nOF HAWAII',
#   'HUI NO KE Gyo OLA PONO',
#   'Ewor ke kajjit6k ko? Kall ae lok (808) 495-5113',
#   'LCHC\nEm6j kdkkaal melele ilo 10/18/23'],
#  'Chuukese': ['ey CERTIFIED COMMUNITY WE ST MAU | AN GAN G E N',
#   '5 “41: BEHAVIORAL HEALTH CLINIC',
#   'MAP aus counry ANINISIN SAFEI KENA',
#   '©)igneuceols  Angangen Aninisin Nenien\nSafei Kena Non Neniach',
#   'Lahaina Comprehensive Health Center\nAninisin Safei kena Semwenin Napenap',
#   'Awan angang kena: Sarinfan - Animu Awan angang kena: Sarinfan - Raninfan\n9:00 AM - 4:00 PM 9:00 AM - 4:00 PM\nla sipwe kokono ie: (808) 871-7772 la sipwe kokono ie: (808) 495-5113\nRa kan Peseieno Appointment kena Chon Fetanenong Repwene Anisir\nRa Asepa Insurens Medicare, Medicaid Ra Asepa Insurens Nge Resapw Pwan Mochenino\n& watten insurens plans (chienon chok oe\nKaiser, Humana & Tricare) Angangen Aninisin Aramas Nap',
#   'we & Enuwon Kena\nAngagen aninis kena',
#   'e Safean Aramas Nap: Sarinfan-Animu « Amwenin Nenien Aninis',
#   'e Tumunun Menukon kena: Sarifan e Counselin Aninis: Emon me emon, Mwich,\ne Achufengenin Safei: Aruwow me pwan Family —',
#   'e Tumunun Ngii: Awunungat e Nemenemen Safei',
#   'e Aninisin psychiatric',
#   'e Angangen Aninisin Osupwangen Eaean\nSafeingaw ren Chon Semwen Nukun Pioin',
#   'e Mwichen Aninisin Pechakuneno -\nSamesam me Inein, Nemenemen\nMefingaw & Ekkiekieochun',
#   '9 @ = legen Civic Center : :\nComey Tels Chiechiech kena\nLahaina Comprehensive Mauliola\nHealth Center Pharmacy',
#   'CLINICAL LABS\nOF HAWAII',
#   'Nenien:',
#   'Akoakoa Place (ettiw won ewe',
#   '<Z\nan seni Lahaina Civic Center) HUI NO KE Gy OLA PONG',
#   'Wayside Park',
#   'ntpark with BBQs & pavilior',
#   'Kapaseis kena? Kori (808) 495-5113',
#   'fan\\\n*Awa kena me pwan angangen aninis kena repwene fofor ngeni asiwinino LCHC\nWest Maui Health Services, Updated 10/18/23 Asofono 10/18/23',
#   'Chuukese'],
#  'Pohnpeian': ['& sewn nenmcme SAVY AS SANG WEST MAUI HEALTH',
#   'MAUI COUNTY',
#   'Hy, = e e\n@) Malama Lice ole Sawas en Local Clinic',
#   'Lahaina Comprehensive Health Center',
#   'Sawas en Wini kan',
#   'Awa kan: Ni Ed lel Ni Alem',
#   '9:00 Ni Menseng lel 4:00 Ni Souwas',
#   'Eker Nempe wet: (808) 871-7772\nAnahne Koasoanehdi Rahn en Kohdo',
#   'Se Ale Insurance: Medicare, Medicaid\noh insurance laud teikan (ahpw kaidehn\nKaiser, Humana oh Tricare)',
#   'Sawas kan',
#   'e Sawas en Wini ong Aramas Laud: Ni Ed lel Ni\nAre',
#   'e Toahkte en seri kan: Ni Ed',
#   'e Sawas Kan Koaros ong Roson: Ni Are',
#   'e Wie Ngih: Ni Esil',
#   '9 @ Lahaina Civic Center',
#   'Lahaina Civic\nCenter Tickets',
#   'Lahaina Comprehensive\nHealth Center',
#   'Akoakoa Place (mih pahnangihn\nLahaina Civic Center)',
#   'Wayside Park',
#   'htpark with BBQs & pavilions',
#   'fan\\',
#   '*Awa oh sawas kan kak wekila',
#   'West Maui Health Services, Updated 10/18/23\nPohnpeian',
#   'Roson en Wiewia de',
#   'Mwekimwekid en\nAramas',
#   'Awa kan: Ni Ed lel Rahn Sarawi\n9:00 Ni Menseng lel 4:00 Ni Souwas\nEker Nempe wet: (808) 495-5113\nKak Pil Kohdohte Pidelong\nSe Ale Insurance Ahpw Kaidehn Anahn Ehu',
#   'Sawas ong Aramas Laud oh\nMe Pwulopwul kan',
#   'e lren Kaweid ong Sawas kan',
#   'e Sawas en Kihda Kaweid: Emenemen\nAramas, Pwihn Ehu, oh Peneinei',
#   'e Kosoandi en Wini Kan',
#   'e Sawas Kan En Madamadau',
#   'e Sawas Kan Ong Aramas Me Doadoahnkgi\nWini Suwed Ahpw Sohte Mih Nan Wasahn\nWini',
#   'e Pwihn En Kihda Sawas En Mour Mwahu -\nPwukoa en Pahpah oh Nohno, Apwalih\nPwunod oh Kolehdi Madamadau Mwahu',
#   'langaht kan',
#   'Mauliola\nPharmacy',
#   'CLINICAL LABS\nOF HAWAII',
#   'HUI NO KE @y@ OLA PONO\nMie Kalelapak? Eker (808) 495-5113',
#   'LCHC\nKakapwla ni October 18, 2023'],
#  'Tongan': ['SSR certiriep comMUNITY\nMga): BEHAVIORAL HEALTH CLINIC\n“Mex; — MAUL COUNTY',
#   ')\nOF =\nDAE Malama I Ke Ola',
#   'HEALTH CENTER',
#   'Ngaahi Ngaue\nFakafaito’6',
#   'WEST MAUI HEALTH SERVICES\nNgaahi ngaue ‘o\ne Kiliniki Fakafeitu’d',
#   'Lahaina Comprehensive Health Center',
#   'Tokangaekina ‘oe',
#   '‘U Houa: Monite - Falaite\n9:00 AM - 4:00 PM\nFetu’utaki: (808) 871-7772',
#   'Ngaahi ‘Apoinimeni ‘Oku Fokotu’u Atu\nTali ‘a e Malu’i Mo’ui: Medicare, Medicaid',
#   "& ngaahi palani malu'i mo'ui lalahi\n(tukukehe ‘a e Kaiser, Humana & Tricare)",
#   "Ngaahi Ngaué\nFaito’o ki he Kakai Lalahi: MGnite-Falaite\nLonga’ifanau: Monite\nMo'ui Fakalukufua: Tisite\nTokangaekina ‘o e Nifé: Pulelulu",
#   '9 Lahaina Civic Center\nfell ahaina Civic',
#   'Center Tickets',
#   'Lahaina Comprehensive\nHealth Center',
#   'Feitu’U:\n‘Api Akoaroa Place (‘i lalo ‘i he',
#   'senita Lahaina Civic Center)',
#   'ntipark with BBQs & pavilions',
#   'faa\n*E ala liliu e ngaahi houa mo e ngaahi ngaué\nWest Maui Health Services, Updated 10/18/23\nTongan',
#   'Td’onga Mo’ui',
#   '‘U Houa: Monite - Sapate\n9:00 AM - 4:00 PM\nFetu’utaki: (808) 495-5113',
#   'Talitali Lelei ‘a e A’utonu Mai Ta’e‘apoinimeni',
#   "‘Oku Tali ‘a e Malu’i Mo'ui Lelei ka ‘Oku ‘ikai\nTu’utu’unia\nNgaahi Ngaue ma’a e Kakai\nLalahi & To’utupu",
#   "Ngaahi Ma’unga Fakamatala Fakahinohind\nTokoni Fale’i: Fakafo'ituitui, Kulupu mo e Famili\nPule’i ‘o e Faito’d",
#   'Ngaahi Ngaue Tokoni Faka’atamai',
#   'Ngaahi Ngaue Tokoni Va’a Ki Tu’a kia',
#   'Kinautolu ‘Oku Palopalema ‘i Hono',
#   'Ngaue’aki ‘o e Faito’o Konatapu',
#   'Ngaahi Kulupu Tokoni ki he Lelei Fakalukufua -\nTauhi ‘o e Fanau, Pule’i e Mafasia e Fakakaukau\n& Tokangaekina ‘o e Fakakaukau',
#   'Ngaahi Hoa Ngaué',
#   'Mauliola\nPharmacy',
#   'CLINICAL LABS\nOF HAWAII',
#   'HUI NO KE gg OLA PONO',
#   "‘Oku ‘i ai ha ngaahi fehu'i?\nTelefoni ki he (808) 495-5113",
#   'LCHC\nLiliu Fakamuimuitaha 10/18/23'],
#  'Kosraean': ['STE',
#   'OS\na _\nDAE Malama I Ke Ola',
#   'y <. CERTIFIED COMMUNITY\nfhaly',
#   'BEHAVIORAL HEALTH CLINIC\nMAUI COUNTY',
#   'HEALTH CENTER',
#   'MWE KAHSRUH SIN WEST MAUI HEALTH\nMwe Kahsruh Ke Local Clinic',
#   'Lahaina Comprehensive Health Center',
#   'ntipark with B',
#   'Mwe Kahsruh luhn Ono',
#   'Ao: Monday nuhke Friday',
#   '9:00 Litutacng nuhke 4:00 Infulwacn lwen',
#   'Pahngohn nacmpuh inge: (808) 871-7772\nAhkkweyeyck in Oraclah Appointment',
#   'Kuht Eis Insurance: Medicare, Medicaid ac\noakwuck in insurance sahyac (sahyacn\nKaiser, Humana ac Tricare)',
#   'Kahsruh ma orek',
#   'e Ono luhn Mwet Mahtuh Monday nuhke\nFriday',
#   'e Taktuh luhn Tuhlihk: Monday',
#   'e Kahsruh Nuhkewa nuhke Health: Tuesday',
#   'e Orek Us: Wednesday',
#   '9 Lahaina Civic Center\nPshaina Civic',
#   'Center Tickets',
#   'Lahaina Comprehensive\nHealth Center',
#   'Acn:',
#   'Akoakoa Place (acn ten liki\nLahaina Civic Center)',
#   'Wayside Park\nBBQs & pavilions',
#   'fan\\',
#   '*Ao ac kahsruh uh kuh na in eklac',
#   'West Maui Health Services, Updated 10/18/23\nKosraean',
#   'Kahsruh nuhke Mukwikwi',
#   'luhn Mwet se',
#   'Ao: Monday nuhke Sunday',
#   '9:00 Litutacng nuhke 4:00 Infulwacn lwen',
#   'Pahngohn nacmpuh inge: (808) 495-5113\nKom kuh In Tuhkuh Pacna',
#   'Kuht Eis Insurance Tuh Tiac Enenuh SE',
#   'Kahsruh nuhsin Mwet',
#   'Mahtuh ac Mwet Fuhsr',
#   'Kahs in Kahsruh nuhke Mwe Kahsruh uh\nSang Kahs In Kahsruh: Mwet se mwet se,\nU in Mwet, ac Sucu',
#   'e Oakwuck nuhke Eisyacn Ono',
#   'Kahsruh nuhke Mwe Nuhnak (Psychiatric)\nKahsruh nuhsin Mwet Mas Ke Ono Kuluk\nma Tiac Muhta luun Acn in Ono',
#   'U in Mwet Ma Tuhkweni Eis Kahsruh -\nNuhsin Pahpa Ninac, Karingihnyen\nNuhnak Fosrng ac Elyah',
#   'Partner lasr',
#   'Mauliola\nPharmacy',
#   'CLINICAL LABS\nOF HAWAII',
#   'HUI NO KE Gyo OLA PONO',
#   'Oasr Kihsen Siyuck? Pahngon (808) 495-5113',
#   'LCHC\nAhksasucyeyucklac ke October 18, 2023']}
