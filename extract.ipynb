# %%
import requests
from io import BytesIO
from pdfminer.layout import LAParams, LTTextBox, LTTextLine
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
import pandas as pd

# %%
pdf_urls = {
    "English": "https://health.hawaii.gov/mauiwildfires/files/2023/08/DOH-Fact-Sheet-Lahaina-CHC.pdf",
    "Hawaiian": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_HAW.pdf",
    "Marshallese": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_MH.pdf",
    "Chuukese": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_CHK.pdf",
    "Pohnpeian": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_PON.pdf",
    "Tongan": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_TO.pdf",
    "Kosraean": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_KOS.pdf",
}

# %%
def download_pdf(url):
    response = requests.get(url)
    return BytesIO(response.content)

# %%
def clean_paragraph(paragraph):
    remove_chars = ["•", "", "\n"]
    for char in remove_chars:
        paragraph = paragraph.replace(char, "")
    return paragraph.strip()

# %%
def extract_text_with_location(pdf_file):
    resource_manager = PDFResourceManager()
    laparams = LAParams()
    device = PDFPageAggregator(resource_manager, laparams=laparams)
    interpreter = PDFPageInterpreter(resource_manager, device)
    
    text_with_locations = []  # List to hold text and its locations
    for page in PDFPage.get_pages(pdf_file):
        interpreter.process_page(page)
        layout = device.get_result()
        for element in layout:
            if isinstance(element, LTTextBox) or isinstance(element, LTTextLine):
                x0, y0, x1, y1 = element.bbox
                first_line = True  # Flag to mark the first line of a paragraph
                for text_line in element:
                    if isinstance(text_line, LTTextLine):
                        text = clean_paragraph(text_line.get_text())
                        # If the first line of a paragraph or a single-line paragraph, take its y-coordinate
                        if text and first_line:
                            y_coordinate = y0
                            first_line = False
                        text_with_locations.append((y_coordinate, text))
                first_line = True  # Reset the flag for the next text box
    return text_with_locations

# %%
texts_by_language = {}
locations_by_language = {}

for language, url in pdf_urls.items():
    pdf_file = download_pdf(url)
    text_and_locations = extract_text_with_location(pdf_file)
    
    # Separate text and location information
    locations_by_language[language], texts_by_language[language] = zip(*text_and_locations)

# Find the maximum number of paragraphs across all languages to ensure DataFrame completeness
max_paragraphs = max(len(paragraphs) for paragraphs in texts_by_language.values())

# Create a list of dictionaries for each paragraph across all languages
data = []
for i in range(max_paragraphs):
    row = {'Location': None}
    for language in pdf_urls.keys():
        if i < len(texts_by_language[language]):
            row[language] = texts_by_language[language][i]
            # Only add location info if it's not already added
            if row['Location'] is None:
                row['Location'] = locations_by_language[language][i]
        else:
            row[language] = ""  # Fill in blank for languages with fewer paragraphs
    data.append(row)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Location                                English  \
# 0   675.410919              WEST MAUI HEALTH SERVICES
# 1   675.410919                  Local Clinic Services
# 2   626.631968    Lāhainā Comprehensive Health Center
# 3   574.329886                       Medical Services
# 4   574.399349                      Behavioral Health
# 5   507.209547                 Hours: Monday - Friday
# 6   507.209547                      9:00 AM – 4:00 PM
# 7   507.209547                Contact: (808) 871-7772
# 8   490.709548               Appointments Recommended
# 9   432.301921          Insurance Accepted: Medicare,
# 10  432.301921       Medicaid & major insurance plans
# 11  432.301921      (except Kaiser, Humana & Tricare)
# 12  402.346307                               Services
# 13  329.401926          Adult Medicine: Monday-Friday
# 14  329.401926                     Pediatrics: Monday
# 15  329.401926             Integrated Health: Tuesday
# 16  329.401926                 Dental Care: Wednesday
# 17  507.209547                 Hours: Monday - Sunday
# 18  507.209547                      9:00 AM – 4:00 PM
# 19  507.209547                Contact: (808) 495-5113
# 20  490.709548                       Walk-Ins Welcome
# 21  470.721256    Insurance Accepted But Not Required
# 22  287.114995                 Adult & Youth Services
# 23  287.114995                      Resource Guidance
# 24  287.114995     Supportive Counseling: Individual,
# 25  287.114995                      Group, and Family
# 26  287.114995                  Medication Management
# 27  287.114995                   Psychiatric Services
# 28  287.114995      Outpatient Substance Use Disorder
# 29  287.114995                               Services
# 30  287.114995   Wellness Support Groups – Parenting,
# 31  287.114995        Stress Management & Mindfulness
# 32  235.304801                               Partners
# 33   84.006079                              Location:
# 34   84.006079              Ākoakoa Place (just below
# 35   84.006079                  Lāhainā Civic Center)
# 36   12.815279  *Hours and services subject to change
# 37   60.114379         Questions? Call (808) 495-5113
# 38   12.815279                                   LCHC
# 39   12.815279                       Updated 10/18/23
# 40    3.537800
# 41   63.222570
# 42   63.222570
# 43   17.062452
# 44   17.062452
# 45   17.524800
# 46   59.044800
# 47   17.510400
#
#                                         Hawaiian  \
# 0                      WEST MAUI HEALTH SERVICES
# 1                          Nā Hana Lawelawe o nā
# 2                            Ke‘ena Kauka Kūloko
# 3            Lāhainā Comprehensive Health Center
# 4                       Nā Hana Lawelawe Olakino
# 5                     Kūlana No‘ono‘o i ka Hanah
# 6                   Nā Hola: Pō‘akahi – Pō‘alima
# 7                              9:00 AM – 4:00 PM
# 8                       Kelepona: (808) 871-7772
# 9                     Nā Hola: Pō‘akahi – Lāpule
# 10                             9:00 AM – 4:00 PM
# 11                      Kelepona: (808) 495-5113
# 12            Paipai ‘ia e Ho‘opa‘a i ka Hālāwai
# 13                 ‘Ae ‘ia ka Po‘e Komo Wale mai
# 14   ‘Ae ‘ia ka ‘Inikua: Medicare, Medicaid a me
# 15     nā papa hana ‘inikua inoa kaulana (koe ke
# 16                     Kaiser, Humana & Tricare)
# 17                              Nā Hana Lawelawe
# 18          ‘Ae ‘ia ka ‘Inikua, akā, ‘A‘ole Pono
# 19                 Nā Hana Lawelawe no nā Kānaka
# 20                           Mākua a me nā ‘Ōpio
# 21                          Kuhikuhi Kumu Waiwai
# 22       Lā‘au Kānaka Makua: Pō‘akahi – Pō‘alima
# 23  Kauleo Kāko‘o: No ke Kanaka, ka Hui, a me ka
# 24                       Lapa‘au Keiki: Pō‘akahi
# 25      Nā Nīnau Like ‘Ole o ke Olakino: Pō‘alua
# 26                         Dental Care: Pō‘akolu
# 27                                        ‘Ohana
# 28                        Ho‘omalu Lā‘au Lapa‘au
# 29                         Kauka Kūlana No‘ono‘o
# 30   Nā Hana Lawelawe Hei ‘Ai Lā‘au Pākela no ka
# 31                                    Lā Wale nō
# 32  Nā Hui Kāko‘o Ola Pono – Ka Hana a nā Mākua,
# 33   Ho‘omalu Uluhua a me ka Maluhia o ka Mana‘o
# 34                                   Nā Hoa Hana
# 35                                         Kahi:
# 36               ‘Ākoakoa Place (ma kai iki o ka
# 37                         Lāhaina Civic Center)
# 38   *Hiki ke loli nā hola a me nā hana lawelawe
# 39   West Maui Health Services, Updated 10/18/23
# 40                                      Hawaiian
# 41       Loa‘a nō ka nīnau? E kelepona i ka helu
# 42                                (808) 495-5113
# 43                                          LCHC
# 44                     Ho‘oponopono ‘ia 10/18/23
# 45
# 46
# 47
#
#                                         Marshallese  \
# 0                JIBAÑ IN EJMOUR KO ILO RĀK IN MAUI
# 1                       Jibañ ko ilo Jikin Taktõ ko
# 2                             Redik ilo Jukjukinbed
# 3               Lāhainā Comprehensive Health Center
# 4                                   Jibañ in Ejmour
# 5                             Nañinmij ko ilo Manit
# 6                           Awa ko: Mande - Bolaide
# 7                             Awa ko: Mande - Jabot
# 8                 9:00 Awa Jibbon – 4:00 Awa Raelap
# 9                 9:00 Awa jibbon – 4:00 Awa Raelap
# 10              Nomba eo ñan Kebaak: (808) 871-7772
# 11              Nomba eo ñan Kebaak: (808) 495-5113
# 12      Emõj Rõjañ Karõk Awa im Raan eo Kwõnaj Etal
# 13               Rej Karuwainene an Armij Kaju Itok
# 14              Rej Ebõk Injuran Medicare, Medicaid
# 15         & im injuran ko relab (ijellokun Kaiser,
# 16                                Humana & Tricare)
# 17                               Jerbal in Jibañ ko
# 18           Jikin Taktõ eo an Rūtto: Mande-Bolaide
# 19                   Jikin Taktõ eo an Ajiri: Mande
# 20                          Integrated Health: Tuje
# 21                               Taktõ in Ñi: Wenje
# 22  Rej Ebõk Injuran Bõtab Ejab Mennin Aikuj an Wõr
# 23                       Jibañ ñan Rūtto & Jodikdik
# 24               Melele in Kajinet kin Mennin Jibañ
# 25           Koonjel ñan Lelok Jibañ: Kajojo Armij,
# 26                         Kumi in Armij, im Baamle
# 27                               Lale Ien Ebõk Wūno
# 28                       Jibañ ko ilo Wāween Lomnak
# 29           Jibañ ko ñan Jorrāān jen Kõjerbal Wūno
# 30       Kajur ilo an Rinañinmij Jab Deloñ Aujbitol
# 31           Kumi in Jibañ kin Ainemmon im Ejmour -
# 32               Nejnej, Lale Inebata & Jela Lomnak
# 33                       Jikin ko jej Jerbal Ibbeir
# 34                                           Jikin:
# 35                        Ākoakoa Place (ilalin wõt
# 36                            Lāhainā Civic Center)
# 37
# 38         *Awa in jerbal in jibañ ko remaron oktak
# 39      West Maui Health Services, Updated 10/18/23
# 40                                      Marshallese
# 41  Ewõr ke kajjitõk ko? Kall ae lok (808) 495-5113
# 42                                             LCHC
# 43                 Emõj kõkkāāl melele ilo 10/18/23
# 44
# 45
# 46
# 47
#
#                                              Chuukese  \
# 0                                  WEST MAUI ANGANGEN
# 1                                 ANINISIN SAFEI KENA
# 2                            Angangen Aninisin Nenien
# 3                              Safei Kena Non Neniach
# 4                 Lāhainā Comprehensive Health Center
# 5                                 Aninisin Safei kena
# 6                                    Semwenin Napenap
# 7                  Awan angang kena: Sarinfan - Animu
# 8                                   9:00 AM – 4:00 PM
# 9                  Ia sipwe kokono ie: (808) 871-7772
# 10                   Ra kan Peseieno Appointment kena
# 11               Ra Asepa Insurens Medicare, Medicaid
# 12              & watten insurens plans (chienon chok
# 13                          Kaiser, Humana & Tricare)
# 14                                Angagen aninis kena
# 15                  Safean Aramas Nap: Sarinfan-Animu
# 16                      Tumunun Menukon kena: Sarifan
# 17                         Achufengenin Safei: Aruwow
# 18                            Tumunun Ngii: Awunungat
# 19              Awan angang kena: Sarinfan - Raninfan
# 20                                  9:00 AM – 4:00 PM
# 21                 Ia sipwe kokono ie: (808) 495-5113
# 22                     Chon Fetanenong Repwene Anisir
# 23        Ra Asepa Insurens Nge Resapw Pwan Mochenino
# 24                       Angangen Aninisin Aramas Nap
# 25                                      & Enuwon Kena
# 26                              Amwenin Nenien Aninis
# 27             Counselin Aninis: Emon me emon, Mwich,
# 28                                     me pwan Family
# 29                                    Nemenemen Safei
# 30                               Aninisin psychiatric
# 31                 Angangen Aninisin Osupwangen Eaean
# 32              Safeingaw ren Chon Semwen Nukun Pioin
# 33                     Mwichen Aninisin Pechakuneno -
# 34                        Samesam me Inein, Nemenemen
# 35                           Mefingaw & Ekkiekieochun
# 36                                    Chiechiech kena
# 37                                            Nenien:
# 38                       Ākoakoa Place (ettiw won ewe
# 39                      an seni Lāhainā Civic Center)
# 40
# 41  *Awa kena me pwan angangen aninis kena repwene...
# 42        West Maui Health Services, Updated 10/18/23
# 43                                           Chuukese
# 44                                               LCHC
# 45                                   Asofono 10/18/23
# 46                 Kapaseis kena? Kori (808) 495-5113
# 47
#
#                                       Pohnpeian  \
# 0                   SAWAS SANG WEST MAUI HEALTH
# 1                         Sawas en Local Clinic
# 2           Lāhainā Comprehensive Health Center
# 3                             Sawas en Wini kan
# 4                    Awa kan: Ni Ed lel Ni Alem
# 5            9:00 Ni Menseng lel 4:00 Ni Souwas
# 6                Eker Nempe wet: (808) 871-7772
# 7              Anahne Koasoanehdi Rahn en Kohdo
# 8          Se Ale Insurance: Medicare, Medicaid
# 9        oh insurance laud teikan (ahpw kaidehn
# 10                   Kaiser, Humana oh Tricare)
# 11                                    Sawas kan
# 12  Sawas en Wini ong Aramas Laud: Ni Ed lel Ni
# 13                                          Are
# 14                   Toahkte en seri kan: Ni Ed
# 15                           Roson en Wiewia de
# 16                               Mwekimwekid en
# 17                                       Aramas
# 18               Awa kan: Ni Ed lel Rahn Sarawi
# 19           9:00 Ni Menseng lel 4:00 Ni Souwas
# 20               Eker Nempe wet: (808) 495-5113
# 21                    Kak Pil Kohdohte Pidelong
# 22      Se Ale Insurance Ahpw Kaidehn Anahn Ehu
# 23                     Sawas ong Aramas Laud oh
# 24                             Me Pwulopwul kan
# 25                    Iren Kaweid ong Sawas kan
# 26              Sawas en Kihda Kaweid: Emenemen
# 27           Sawas Kan Koaros ong Roson: Ni Are
# 28               Aramas, Pwihn Ehu, oh Peneinei
# 29                            Wie Ngih: Ni Esil
# 30                                        Wasa:
# 31                Ākoakoa Place (mih pahnangihn
# 32                        Lāhainā Civic Center)
# 33                         Kosoandi en Wini Kan
# 34                       Sawas Kan En Madamadau
# 35          Sawas Kan Ong Aramas Me Doadoahnkgi
# 36         Wini Suwed Ahpw Sohte Mih Nan Wasahn
# 37                                         Wini
# 38         Pwihn En Kihda Sawas En Mour Mwahu –
# 39           Pwukoa en Pahpah oh Nohno, Apwalih
# 40            Pwunod oh Kolehdi Madamadau Mwahu
# 41                                  Iangaht kan
# 42                 *Awa oh sawas kan kak wekila
# 43           Mie Kalelapak? Eker (808) 495-5113
# 44  West Maui Health Services, Updated 10/18/23
# 45                                    Pohnpeian
# 46                                         LCHC
# 47                 Kakapwla ni October 18, 2023
#
#                                                Tongan  \
# 0                           WEST MAUI HEALTH SERVICES
# 1                                     Ngaahi ngāue ‘o
# 2                              e Kilīniki Fakafeitu’ú
# 3                 Lāhainā Comprehensive Health Center
# 4                                        Ngaahi Ngāue
# 5                                         Fakafaito’ó
# 6                                   Tokangaekina ‘o e
# 7                                       Tō’onga Mo’uí
# 8                           ‘Ū Houá: Mōnite - Falaite
# 9                                   9:00 AM – 4:00 PM
# 10                         Fetu’utaki: (808) 871-7772
# 11                           ‘Ū Houá: Mōnite - Sāpate
# 12                                  9:00 AM – 4:00 PM
# 13                         Fetu’utaki: (808) 495-5113
# 14               Ngaahi ‘Apoinimeni ‘Oku Fokotu’u Atú
# 15    Talitali Lelei ‘a e A’utonu Mai Ta’e’apoinimení
# 16         Tali ‘a e Malu’i Mo’ui: Medicare, Medicaid
# 17                & ngaahi palani malu’i mo’ui lalahi
# 18           (tukukehe ‘a e Kaiser, Humana & Tricare)
# 19                                       Ngaahi Ngāué
# 20         Faito’o ki he Kakai Lalahí: Mōnite-Falaite
# 21                               Longa’ifānaú: Mōnite
# 22                          Mo’ui Fakalukufuá: Tūsite
# 23                   Tokangaekina ‘o e Nifó: Pulelulu
# 24    ‘Oku Tali ‘a e Malu’i Mo’ui Leleí ka ‘Oku ‘ikai
# 25                                        Tu’utu’unia
# 26                          Ngaahi Ngāue ma’a e Kakai
# 27                                  Lalahí & To’utupú
# 28             Ngaahi Ma’unga Fakamatala Fakahinohinó
# 29  Tokoni Fale’i: Fakafo’ituitui, Kulupu mo e Fāmili
# 30                                Pule’i ‘o e Faito’ó
# 31                    Ngaahi Ngāue Tokoni Faka’atamaí
# 32               Ngaahi Ngāue Tokoni Va’a Ki Tu’a kia
# 33                  Kinautolu ‘Oku Palopalema ‘i Hono
# 34                    Ngāue’aki ‘o e Faito’o Konatapú
# 35     Ngaahi Kulupu Tokoni ki he Lelei Fakalukufuá -
# 36    Tauhi ‘o e Fānaú, Pule’i e Mafasia e Fakakaukaú
# 37                     & Tokangaekina ‘o e Fakakaukaú
# 38                                   Ngaahi Hoa Ngāué
# 39                                           Feitu’ú:
# 40                                      Civic Center)
# 41      *’E ala liliu e ngaahi houá mo e ngaahi ngāué
# 42        West Maui Health Services, Updated 10/18/23
# 43                                             Tongan
# 44                       ‘Oku ‘i ai ha ngaahi fehu’i?
# 45                      Telefoni ki he (808) 495-5113
# 46                                               LCHC
# 47                      Liliu Fakamuimuitahá 10/18/23
#
#                                        Kosraean
# 0              MWE KAHSRUH SIN WEST MAUI HEALTH
# 1                   Mwe Kahsruh Ke Local Clinic
# 2           Lāhainā Comprehensive Health Center
# 3                          Mwe Kahsruh luhn Ono
# 4                       Ao: Monday nuhke Friday
# 5      9:00 Litutacng nuhke 4:00 Infulwacn lwen
# 6         Pahngohn nacmpuh inge: (808) 871-7772
# 7            Ahkkweyeyck in Oraclah Appointment
# 8     Kuht Eis Insurance: Medicare, Medicaid ac
# 9          oakwuck in insurance sahyac (sahyacn
# 10                   Kaiser, Humana ac Tricare)
# 11                              Kahsruh ma orek
# 12            Ono luhn Mwet Mahtuh Monday nuhke
# 13                                       Friday
# 14                  Taktuh luhn Tuhlihk: Monday
# 15        Kahsruh Nuhkewa nuhke Health: Tuesday
# 16                           Orek Us: Wednesday
# 17                                         Acn:
# 18                  Ākoakoa Place (acn ten liki
# 19                        Lāhainā Civic Center)
# 20                       Kahsruh nuhke Mukwikwi
# 21                                 luhn Mwet se
# 22                      Ao: Monday nuhke Sunday
# 23     9:00 Litutacng nuhke 4:00 Infulwacn lwen
# 24        Pahngohn nacmpuh inge: (808) 495-5113
# 25                      Kom Kuh In Tuhkuh Pacna
# 26        Kuht Eis Insurance Tuh Tiac Enenuh SE
# 27                          Kahsruh nuhsin Mwet
# 28                         Mahtuh ac Mwet Fuhsr
# 29         Kahs in Kahsruh nuhke Mwe Kahsruh uh
# 30       Sang Kahs In Kahsruh: Mwet se mwet se,
# 31                           U in Mwet, ac Sucu
# 32                    Oakwuck nuhke Eisyacn Ono
# 33       Kahsruh nuhke Mwe Nuhnak (Psychiatric)
# 34         Kahsruh nuhsin Mwet Mas Ke Ono Kuluk
# 35                ma Tiac Muhta luun Acn in Ono
# 36          U in Mwet Ma Tuhkweni Eis Kahsruh –
# 37             Nuhsin Pahpa Ninac, Karingihnyen
# 38                       Nuhnak Fosrng ac Elyah
# 39                                 Partner lasr
# 40            *Ao ac kahsruh uh kuh na in eklac
# 41   Oasr Kihsen Siyuck? Pahngon (808) 495-5113
# 42  West Maui Health Services, Updated 10/18/23
# 43                                     Kosraean
# 44                                         LCHC
# 45        Ahksasucyeyucklac ke October 18, 2023
# 46
# 47
