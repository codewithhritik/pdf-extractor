# %%
import requests
import fitz
import pandas as pd

# %%
pdf_urls = {
    "English": "https://health.hawaii.gov/mauiwildfires/files/2023/08/DOH-Fact-Sheet-Lahaina-CHC.pdf",
    "Hawaiian": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_HAW.pdf",
    "Marshallese": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_MH.pdf",
    "Chuukese": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_CHK.pdf",
    "Pohnpeian": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_PON.pdf",
    "Tongan": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_TO.pdf",
    "Kosraean": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_KOS.pdf"
}

# %%
def fetch_and_extract_text_sorted(url):
    """Fetch a PDF from a URL and extract its text, attempting to sort by position."""
    response = requests.get(url)
    response.raise_for_status()
    sorted_paragraphs = []
    with fitz.open("pdf", response.content) as doc:
        for page in doc:
            blocks = page.get_text("blocks")
            blocks.sort(key=lambda block: (block[1], block[0]))  # Sort by y, then by x
            page_text = [block[4] for block in blocks]
            sorted_paragraphs.append(page_text)
    return sorted_paragraphs

# %%
def clean_and_preprocess(text_blocks):
    """Clean and preprocess text blocks extracted from a PDF."""
    cleaned_text = []
    for page in text_blocks:
        cleaned_page = []
        for text in page:
            text = text.replace('\n', ' ').strip()  # Replace new lines with spaces, remove extra spaces
            # Implement additional cleaning here as needed
            cleaned_page.append(text)
        cleaned_text.append(' '.join(cleaned_page))  # Join all texts in a page into a single string
    return cleaned_text

# %%
fetch_and_extract_text_sorted(pdf_urls["English"])
# Out:
# [['WEST MAUI HEALTH SERVICES\n',
#   'Local Clinic Services\n',
#   'Lāhainā Comprehensive Health Center\n',
#   'Behavioral Health \n',
#   'Medical Services\n',
#   'Hours: Monday - Friday \n9:00 AM – 4:00 PM\nContact: (808) 871-7772\n',
#   'Hours: Monday - Sunday\n9:00 AM – 4:00 PM\nContact: (808) 495-5113\n',
#   'Appointments Recommended\n',
#   'Walk-Ins Welcome\n',
#   'Insurance Accepted But Not Required\n',
#   'Insurance Accepted: Medicare,\n',
#   'Medicaid & major insurance plans\n(except Kaiser, Humana & Tricare)\n',
#   'Adult & Youth Services\n',
#   'Resource Guidance    \nSupportive Counseling: Individual,\nGroup, and Family    \nMedication Management     \nPsychiatric Services      \nOutpatient Substance Use Disorder\nServices\nWellness Support Groups – Parenting,\nStress Management & Mindfulness\n',
#   'Services\n',
#   'Adult Medicine: Monday-Friday\nPediatrics: Monday \nIntegrated Health: Tuesday                        \nDental Care: Wednesday                             \n',
#   'Partners\n',
#   'Location: \n',
#   'Ākoakoa Place (just below\n',
#   'Lāhainā Civic Center)\n',
#   'Questions? Call (808) 495-5113\n',
#   'LCHC\nUpdated 10/18/23\n*Hours and services subject to change\n']]

# %%
fetch_and_extract_text_sorted(pdf_urls["Hawaiian"])
# Out:
# [['WEST MAUI HEALTH SERVICES \nNā Hana Lawelawe o nā \nKe‘ena Kauka Kūloko \n',
#   'Lāhainā Comprehensive Health Center \n',
#   'Nā Hana Lawelawe Olakino\n',
#   'Kūlana No‘ono‘o i ka Hanah\n',
#   'Nā Hola: Pō‘akahi – Pō‘alima \n',
#   'Nā Hola: Pō‘akahi – Lāpule \n',
#   '9:00 AM – 4:00 PM \n',
#   '9:00 AM – 4:00 PM \n',
#   'Kelepona: (808) 871-7772 \n',
#   'Kelepona: (808) 495-5113 \n',
#   'Paipai ‘ia e Ho‘opa‘a i ka Hālāwai \n',
#   '‘Ae ‘ia ka Po‘e Komo Wale mai \n',
#   '‘Ae ‘ia ka ‘Inikua: Medicare, Medicaid a me \n',
#   '‘Ae ‘ia ka ‘Inikua, akā, ‘A‘ole Pono \n',
#   'nā papa hana ‘inikua inoa kaulana (koe ke \n',
#   'Nā Hana Lawelawe no nā Kānaka \nMākua a me nā ‘Ōpio \n',
#   'Kaiser, Humana & Tricare) \n',
#   'Nā Hana Lawelawe \n',
#   '\uf03d Kuhikuhi Kumu Waiwai \n',
#   '\uf03d Lā‘au Kānaka Makua: Pō‘akahi – Pō‘alima \n',
#   '\uf03d Kauleo Kāko‘o: No ke Kanaka, ka Hui, a me ka \n',
#   '\uf03d Lapa‘au Keiki: Pō‘akahi \n',
#   '‘Ohana \n',
#   '\uf03d Nā Nīnau Like ‘Ole o ke Olakino: Pō‘alua  \n',
#   '\uf03d Ho‘omalu Lā‘au Lapa‘au  \n',
#   '\uf03d Dental Care: Pō‘akolu \n',
#   '\uf03d Kauka Kūlana No‘ono‘o \n',
#   '\uf03d Nā Hana Lawelawe Hei ‘Ai Lā‘au Pākela no ka \n',
#   'Lā Wale nō \n',
#   '\uf03d Nā Hui Kāko‘o Ola Pono – Ka Hana a nā Mākua, \n',
#   'Ho‘omalu Uluhua a me ka Maluhia o ka Mana‘o \n',
#   'Nā Hoa Hana\n',
#   'Kahi: \n‘Ākoakoa Place (ma kai iki o ka \nLāhaina Civic Center) \n',
#   'Loa‘a nō ka nīnau? E kelepona i ka helu \n(808) 495-5113\n',
#   'LCHC\nHo‘oponopono ‘ia 10/18/23\n',
#   '*Hiki ke loli nā hola a me nā hana lawelawe \nWest Maui Health Services, Updated 10/18/23 \nHawaiian\n']]

# %%
language_paragraphs = {lang: fetch_and_extract_paragraphs(url) for lang, url in pdf_urls.items()}

# %%
mappings = []
for i in range(len(language_paragraphs["English"])):  # Assuming 'en' (English) as the base
    row = {lang: language_paragraphs[lang][i] for lang in language_paragraphs}
    mappings.append(row)

# %%
df_mappings = pd.DataFrame(mappings)

# %%
df_mappings
# Out:
#                                               English  \
# 0                           WEST MAUI HEALTH SERVICES
# 1                               Local Clinic Services
# 2                                  Behavioral Health
# 3                                            Partners
# 4                                    Medical Services
# 5                                          Location:
# 6                           Ākoakoa Place (just below
# 7                               Lāhainā Civic Center)
# 8                 Lāhainā Comprehensive Health Center
# 9                             Hours: Monday - Friday
# 10                                  9:00 AM – 4:00 PM
# 11                            Contact: (808) 871-7772
# 12                           Appointments Recommended
# 13                      Insurance Accepted: Medicare,
# 14                   Medicaid & major insurance plans
# 15                  (except Kaiser, Humana & Tricare)
# 16                      Adult Medicine: Monday-Friday
# 17                                Pediatrics: Monday
# 18  Integrated Health: Tuesday                    ...
# 19  Dental Care: Wednesday                        ...
# 20                                           Services
# 21                             Hours: Monday - Sunday
# 22                                  9:00 AM – 4:00 PM
# 23                            Contact: (808) 495-5113
# 24                                   Walk-Ins Welcome
# 25                              Resource Guidance
# 26                 Supportive Counseling: Individual,
# 27                              Group, and Family
# 28                         Medication Management
# 29                         Psychiatric Services
# 30                  Outpatient Substance Use Disorder
# 31                                           Services
# 32               Wellness Support Groups – Parenting,
# 33                    Stress Management & Mindfulness
# 34                             Adult & Youth Services
# 35                     Questions? Call (808) 495-5113
# 36                Insurance Accepted But Not Required
# 37                                               LCHC
# 38                                   Updated 10/18/23
# 39              *Hours and services subject to change
# 40
#
#                                            Hawaiian  \
# 0                                              LCHC
# 1                         Ho‘oponopono ‘ia 10/18/23
# 2                        WEST MAUI HEALTH SERVICES
# 3                            Nā Hana Lawelawe o nā
# 4                              Ke‘ena Kauka Kūloko
# 5              Lāhainā Comprehensive Health Center
# 6                          Nā Hana Lawelawe Olakino
# 7                     Nā Hola: Pō‘akahi – Pō‘alima
# 8                                9:00 AM – 4:00 PM
# 9                         Kelepona: (808) 871-7772
# 10              Paipai ‘ia e Ho‘opa‘a i ka Hālāwai
# 11     ‘Ae ‘ia ka ‘Inikua: Medicare, Medicaid a me
# 12       nā papa hana ‘inikua inoa kaulana (koe ke
# 13                       Kaiser, Humana & Tricare)
# 14                                Nā Hana Lawelawe
# 15        Lā‘au Kānaka Makua: Pō‘akahi – Pō‘alima
# 16                        Lapa‘au Keiki: Pō‘akahi
# 17      Nā Nīnau Like ‘Ole o ke Olakino: Pō‘alua
# 18                          Dental Care: Pō‘akolu
# 19                       Kūlana No‘ono‘o i ka Hanah
# 20                      Nā Hola: Pō‘akahi – Lāpule
# 21                               9:00 AM – 4:00 PM
# 22                        Kelepona: (808) 495-5113
# 23                   ‘Ae ‘ia ka Po‘e Komo Wale mai
# 24            ‘Ae ‘ia ka ‘Inikua, akā, ‘A‘ole Pono
# 25                   Nā Hana Lawelawe no nā Kānaka
# 26                             Mākua a me nā ‘Ōpio
# 27                           Kuhikuhi Kumu Waiwai
# 28   Kauleo Kāko‘o: No ke Kanaka, ka Hui, a me ka
# 29                                          ‘Ohana
# 30                        Ho‘omalu Lā‘au Lapa‘au
# 31                          Kauka Kūlana No‘ono‘o
# 32    Nā Hana Lawelawe Hei ‘Ai Lā‘au Pākela no ka
# 33                                      Lā Wale nō
# 34   Nā Hui Kāko‘o Ola Pono – Ka Hana a nā Mākua,
# 35     Ho‘omalu Uluhua a me ka Maluhia o ka Mana‘o
# 36                                      Nā Hoa Hana
# 37         Loa‘a nō ka nīnau? E kelepona i ka helu
# 38                                   (808) 495-5113
# 39                                           Kahi:
# 40                 ‘Ākoakoa Place (ma kai iki o ka
#
#                                          Marshallese  \
# 0                                              LCHC
# 1           *Awa in jerbal in jibañ ko remaron oktak
# 2                  Emõj kõkkāāl melele ilo 10/18/23
# 3                JIBAÑ IN EJMOUR KO ILO RĀK IN MAUI
# 4                       Jibañ ko ilo Jikin Taktõ ko
# 5                             Redik ilo Jukjukinbed
# 6               Lāhainā Comprehensive Health Center
# 7                                    Jibañ in Ejmour
# 8                          Awa ko: Mande - Bolaide
# 26   Talitali Lelei ‘a e A’utonu Mai Ta’e’apoinimení
# 27   ‘Oku Tali ‘a e Malu’i Mo’ui Leleí ka ‘Oku ‘ikai
# 28                                       Tu’utu’unia
# 29                         Ngaahi Ngāue ma’a e Kakai
# 30                                 Lalahí & To’utupú
# 31           Ngaahi Ma’unga Fakamatala Fakahinohinó
# 32   Tokoni Fale’i: Fakafo’ituitui, Kulupu mo e F...
# 33                             Pule’i ‘o e Faito’ó
# 34                  Ngaahi Ngāue Tokoni Faka’atamaí
# 35             Ngaahi Ngāue Tokoni Va’a Ki Tu’a kia
# 36                 Kinautolu ‘Oku Palopalema ‘i Hono
# 37                   Ngāue’aki ‘o e Faito’o Konatapú
# 38   Ngaahi Kulupu Tokoni ki he Lelei Fakalukufuá -
# 39   Tauhi ‘o e Fānaú, Pule’i e Mafasia e Fakakaukaú
# 40                    & Tokangaekina ‘o e Fakakaukaú
#
#                                        Kosraean
# 0                                         LCHC
# 1             *Ao ac kahsruh uh kuh na in eklac
# 2        Ahksasucyeyucklac ke October 18, 2023
# 3             MWE KAHSRUH SIN WEST MAUI HEALTH
# 4                  Mwe Kahsruh Ke Local Clinic
# 5          Lāhainā Comprehensive Health Center
# 6                         Mwe Kahsruh luhn Ono
# 7                     Ao: Monday nuhke Friday
# 8     9:00 Litutacng nuhke 4:00 Infulwacn lwen
# 9        Pahngohn nacmpuh inge: (808) 871-7772
# 10          Ahkkweyeyck in Oraclah Appointment
# 11   Kuht Eis Insurance: Medicare, Medicaid ac
# 12        oakwuck in insurance sahyac (sahyacn
# 13                  Kaiser, Humana ac Tricare)
# 14                             Kahsruh ma orek
# 15          Ono luhn Mwet Mahtuh Monday nuhke
# 16                                      Friday
# 17                Taktuh luhn Tuhlihk: Monday
# 18      Kahsruh Nuhkewa nuhke Health: Tuesday
# 19                         Orek Us: Wednesday
# 20                      Kahsruh nuhke Mukwikwi
# 21                                luhn Mwet se
# 22                     Ao: Monday nuhke Sunday
# 23    9:00 Litutacng nuhke 4:00 Infulwacn lwen
# 24       Pahngohn nacmpuh inge: (808) 495-5113
# 25                     Kom Kuh In Tuhkuh Pacna
# 26       Kuht Eis Insurance Tuh Tiac Enenuh SE
# 27                         Kahsruh nuhsin Mwet
# 28                        Mahtuh ac Mwet Fuhsr
# 29       Kahs in Kahsruh nuhke Mwe Kahsruh uh
# 30     Sang Kahs In Kahsruh: Mwet se mwet se,
# 31                          U in Mwet, ac Sucu
# 32                  Oakwuck nuhke Eisyacn Ono
# 33     Kahsruh nuhke Mwe Nuhnak (Psychiatric)
# 34       Kahsruh nuhsin Mwet Mas Ke Ono Kuluk
# 35               ma Tiac Muhta luun Acn in Ono
# 36        U in Mwet Ma Tuhkweni Eis Kahsruh –
# 37            Nuhsin Pahpa Ninac, Karingihnyen
# 38                      Nuhnak Fosrng ac Elyah
# 39                                Partner lasr
# 40  Oasr Kihsen Siyuck? Pahngon (808) 495-5113

# %%
# extracted_texts = []

# %%
# for url, language in pdf_links:
#     text = fetch_and_extract_text(url)
#     extracted_texts.append((language, text))

# %%
# aligned_data = [
   
# ]

# %%
# df = pd.DataFrame(extracted_data)

# %%
csv_to_path = "local_clinic_services.csv"
df.to_csv(csv_to_path, index=False)

# %%
# view df
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
