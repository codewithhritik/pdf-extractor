# %%
import io
import requests
from pdfminer.high_level import extract_text
import pandas as pd
from typing import List

# %%
def download_and_extract_text(url: str) -> str:
    response = requests.get(url)
    with io.BytesIO(response.content) as open_pdf_file:
        text = extract_text(open_pdf_file)
    return text

# %%
def split_text(text: str, by_paragraph=True) -> List[str]:
    if by_paragraph:
        return text.split('\n\n')  # Simple paragraph splitting by double newline
    else:
        # This is a simple approach for sentence splitting. You might need a more sophisticated approach for better accuracy.
        return text.replace('\n', ' ').split('. ')

# %%
pdf_urls = {
    "English": "https://health.hawaii.gov/mauiwildfires/files/2023/08/DOH-Fact-Sheet-Lahaina-CHC.pdf",
    "Hawaiian": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_HAW.pdf",
    "Marshallese": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_MH.pdf",
    "Chuukese": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_CHK.pdf",
    "Pohnpeian": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_PON.pdf",
    "Tongan": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_TO.pdf",
    "Kosraean": "https://health.hawaii.gov/mauiwildfires/files/2023/09/DOH-Fact-Sheet-Lahaina-CHC_KOS.pdf"
}

# %%
texts_by_language = {lang: split_text(download_and_extract_text(url)) for lang, url in pdf_urls.items()}

# %%
# To accommodate varying lengths, create a list of dictionaries for each row
data = []
max_length = max(len(texts) for texts in texts_by_language.values())
for i in range(max_length):
    row = {lang: texts[i] if i < len(texts) else '' for lang, texts in texts_by_language.items()}
    data.append(row)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                               English  \
# 0   FREE* Mental Health Services  \nand Support Gr...
# 1        Wailuku Health Center \n     Crisis Menta...
# 2     •  For those experiencing distress as a result
# 3                             of the Maui wildfires
# 4                •  Mental health counseling, trauma
# 5       processing, psychiatric services, resources
# 6   •  Mon-Fri 7:45am - 4:30pm  \n•  121 Mahalani ...
# 7                                    (808) 984-2150
# 8   Lahaina Health Center \nCrisis Mental Health S...
# 9   •  Adult and youth behavioral health services ...
# 10                                    (808) 495-5113
# 11  Maui Child & Adolescent \nMental Health Division
# 12       •  Mental health services to eligible youth
# 13  with severe emotional and/or behavioral \nchal...
# 14                    • \n•  www.Health.Hawaii/camhd
# 15                         Maui Strong Support Group
# 16     •  For those whose life has been disrupted by
# 17                                the Maui wildfires
# 18      •  Please contact NAMI for days and times as
# 19                              they vary each month
# 20  •  95 Mahalani Street, Wailuku \n•  Anisa@NAMI...
# 21                 •  Support for women experiencing
# 22  domestic violence \n•  Hotline: (808) 579-9581...
# 23         •  Peer-to-peer grief support services to
# 24  children and their families \n(808) 214-9832 \...
# 25                       • \n• \n•  www.NKOEMaui.org
# 26   \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n ...
# 27  •  Online mental health screenings \n•  Tools ...
# 28                  conversation about mental health
# 29  •  Maui: (808) 242-6461 \n•  Oahu: (808) 521-1...
# 30  •  Hawaii’s 24/7 Crisis and Referral Line \n• ...
# 31        •  National 24/7 Crisis Line \n•  Dial 988
# 32  •  24/7 Crisis Text Line \n•  Text ALOHA to 74...
# 33      SAMHSA National Disaster \nDistress Helpline
# 34  •  National 24/7 emotional support related \nt...
# 35                   • \n•  Text TalkWithUs to 66746
# 36                                    (866) 488-7386
# 37  •  National 24/7 Hotline for LGBTQ Youth \n• \...
# 38   \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n ...
# 39
# 40
#
#                                              Hawaiian
# 0   MANUAHI* Ke Kōkua no ka Pō‘ino o ka No‘ono‘o \...
# 1   Wailuku Health Center \nKōkua Pō‘ino o ka No‘o...
# 2   Lāhaina Health Center \nKōkua Pō‘ino o ka No‘o...
# 3                                                   •
# 4   • No ka po‘e i lo‘ohia i ka pilihua o ka mana‘...
# 5              •\n•\n•\n• MauiWellness@doh.hawaii.gov
# 6   • Nā hana lawelawe pōpilikia o ka mana‘o\nno n...
# 7                                       •\n•\n•\n•\n•
# 8                            Maui Child & Adolescent
# 9   Māhele Pōpilikia o ka Mana‘o \n(Mental Health ...
# 10                         Maui Strong Support Group
# 11       • No ka po‘e i pōpilikia ai ke ola ma muli o
# 12                                                  •
# 13  Loaʻa nā kōkua hoʻoponopono noʻonoʻo no\nnā ʻō...
# 14                       •\n• www.Health.Hawaii/camhd
# 15                                                  •
# 16  ke ahi nāhelehele ma Maui\nE kūkā me NAMI no n...
# 17                          •\n• Anisa@NAMIHawaii.org
# 18  • Nā hana lawelawe kāko‘o no nā wāhine\nKelepo...
# 19  Free* Mental Health Services and Support Group...
# 20                                                  •
# 21  Kōkua kūkākūkā me nā hoa no nā keiki a\nme ko ...
# 22                           •\n•\n• www.NKOEMaui.org
# 23
# MANUAHI* Ke Kōkua no ka Pō‘ino o ka No‘ono‘o ...
# 24  •\nLoiloi no ke kūlana ola pono o ka mana‘o\n•...
# 25  • Maui: (808) 242-6461\n• O‘ahu: (808) 521-184...
# 26                   • Helu Kelepona A‘oa‘o Pō‘ino ma
# 27                                       Hawai‘i 24/7
# 28  • O‘ahu: (808) 832-3100\n• Nō Mokupuni ‘Ē a‘e:...
# 29            • Helu Kelepona A‘oa‘o Pō‘ino Ā Puni ke
# 30                         Aupuni 24/7\nKaomi aku 988
# 31                                                  •
# 32  • Helu Kelepona Kikokiko no ka Pō‘ino 24/7\nE ...
# 33  SAMHSA National Disaster\nHelu Kelepona Kōkua ...
# 34  • No ke kōkua no nā ‘ano pō‘ino o ka ‘āina ā\n...
# 35                                               •\n•
# 36            • Helu Kelepona A‘oa‘o Pō‘ino Ā Puni ke
# 37  Aupuni 24/7 no nā ‘ōpio LGBTQ\n(866) 488-7386\...
# 38                   •\n•\n• www.TheTrevorProject.org
# 39  Free* Mental Health Services and Support Group...
# 40

# %%
df = pd.DataFrame.from_dict(texts_by_language, orient='index').transpose()

# %%
df
# Out:
#                                               English  \
# 0   FREE* Mental Health Services  \nand Support Gr...
# 1        Wailuku Health Center \n     Crisis Menta...
# 2     •  For those experiencing distress as a result
# 3                             of the Maui wildfires
# 4                •  Mental health counseling, trauma
# 5       processing, psychiatric services, resources
# 6   •  Mon-Fri 7:45am - 4:30pm  \n•  121 Mahalani ...
# 7                                    (808) 984-2150
# 8   Lahaina Health Center \nCrisis Mental Health S...
# 9   •  Adult and youth behavioral health services ...
# 10                                    (808) 495-5113
# 11  Maui Child & Adolescent \nMental Health Division
# 12       •  Mental health services to eligible youth
# 13  with severe emotional and/or behavioral \nchal...
# 14                    • \n•  www.Health.Hawaii/camhd
# 15                         Maui Strong Support Group
# 16     •  For those whose life has been disrupted by
# 17                                the Maui wildfires
# 18      •  Please contact NAMI for days and times as
# 19                              they vary each month
# 20  •  95 Mahalani Street, Wailuku \n•  Anisa@NAMI...
# 21                 •  Support for women experiencing
# 22  domestic violence \n•  Hotline: (808) 579-9581...
# 23         •  Peer-to-peer grief support services to
# 24  children and their families \n(808) 214-9832 \...
# 25                       • \n• \n•  www.NKOEMaui.org
# 26   \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n ...
# 27  •  Online mental health screenings \n•  Tools ...
# 28                  conversation about mental health
# 29  •  Maui: (808) 242-6461 \n•  Oahu: (808) 521-1...
# 30  •  Hawaii’s 24/7 Crisis and Referral Line \n• ...
# 31        •  National 24/7 Crisis Line \n•  Dial 988
# 32  •  24/7 Crisis Text Line \n•  Text ALOHA to 74...
# 33      SAMHSA National Disaster \nDistress Helpline
# 34  •  National 24/7 emotional support related \nt...
# 35                   • \n•  Text TalkWithUs to 66746
# 36                                    (866) 488-7386
# 37  •  National 24/7 Hotline for LGBTQ Youth \n• \...
# 38   \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n ...
# 39                                               None
# 40                                               None
#
#                                              Hawaiian
# 0   MANUAHI* Ke Kōkua no ka Pō‘ino o ka No‘ono‘o \...
# 1   Wailuku Health Center \nKōkua Pō‘ino o ka No‘o...
# 2   Lāhaina Health Center \nKōkua Pō‘ino o ka No‘o...
# 3                                                   •
# 4   • No ka po‘e i lo‘ohia i ka pilihua o ka mana‘...
# 5              •\n•\n•\n• MauiWellness@doh.hawaii.gov
# 6   • Nā hana lawelawe pōpilikia o ka mana‘o\nno n...
# 7                                       •\n•\n•\n•\n•
# 8                            Maui Child & Adolescent
# 9   Māhele Pōpilikia o ka Mana‘o \n(Mental Health ...
# 10                         Maui Strong Support Group
# 11       • No ka po‘e i pōpilikia ai ke ola ma muli o
# 12                                                  •
# 13  Loaʻa nā kōkua hoʻoponopono noʻonoʻo no\nnā ʻō...
# 14                       •\n• www.Health.Hawaii/camhd
# 15                                                  •
# 16  ke ahi nāhelehele ma Maui\nE kūkā me NAMI no n...
# 17                          •\n• Anisa@NAMIHawaii.org
# 18  • Nā hana lawelawe kāko‘o no nā wāhine\nKelepo...
# 19  Free* Mental Health Services and Support Group...
# 20                                                  •
# 21  Kōkua kūkākūkā me nā hoa no nā keiki a\nme ko ...
# 22                           •\n•\n• www.NKOEMaui.org
# 23
# MANUAHI* Ke Kōkua no ka Pō‘ino o ka No‘ono‘o ...
# 24  •\nLoiloi no ke kūlana ola pono o ka mana‘o\n•...
# 25  • Maui: (808) 242-6461\n• O‘ahu: (808) 521-184...
# 26                   • Helu Kelepona A‘oa‘o Pō‘ino ma
# 27                                       Hawai‘i 24/7
# 28  • O‘ahu: (808) 832-3100\n• Nō Mokupuni ‘Ē a‘e:...
# 29            • Helu Kelepona A‘oa‘o Pō‘ino Ā Puni ke
# 30                         Aupuni 24/7\nKaomi aku 988
# 31                                                  •
# 32  • Helu Kelepona Kikokiko no ka Pō‘ino 24/7\nE ...
# 33  SAMHSA National Disaster\nHelu Kelepona Kōkua ...
# 34  • No ke kōkua no nā ‘ano pō‘ino o ka ‘āina ā\n...
# 35                                               •\n•
# 36            • Helu Kelepona A‘oa‘o Pō‘ino Ā Puni ke
# 37  Aupuni 24/7 no nā ‘ōpio LGBTQ\n(866) 488-7386\...
# 38                   •\n•\n• www.TheTrevorProject.org
# 39  Free* Mental Health Services and Support Group...
# 40

# %%
df.to_csv('mappings2.csv', index=False)
